# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dfmhs = pd.read_csv('nilaimahasiswa.csv',sep=';',engine='python')

# %%
dfmhs.describe()
# Out:
#               uts         uas
# count   50.000000   50.000000
# mean    56.220000   60.960000
# std     27.316953   25.235996
# min     12.000000    0.000000
# 25%     30.250000   45.000000
# 50%     55.000000   56.000000
# 75%     71.500000   81.000000
# max    100.000000  100.000000

# %%
dfmhs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Mahasiswa  50 non-null     object
#  1   uts        50 non-null     int64
#  2   uas        50 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 1.3+ KB

# %%
plt.scatter(dfmhs['uts'],dfmhs['uas'])
plt.xlabel("uts")
plt.ylabel("uas")
plt.title("Grafik Nilai Mahasiswa")
# Out:
# Text(0.5, 1.0, 'Grafik Nilai Mahasiswa')

# %% [markdown]
# Membuat Data Training

# %%
x_train = dfmhs[['uts','uas']].values

# %%
x_train
# Out:
# array([[ 15,  46],
#        [ 66,  77],
#        [ 25,  33],
#        [ 53,  81],
#        [ 20,  75],
#        [100,  94],
#        [ 55,  69],
#        [ 25,  56],
#        [ 25,  81],
#        [ 30,  48],
#        [ 15,  45],
#        [ 81,  46],
#        [ 68,  77],
#        [ 72,  50],
#        [ 56,  56],
#        [ 63,  63],
#        [100,  69],
#        [ 35,  56],
#        [ 55,  33],
#        [ 31,  21],
#        [ 55,  22],
#        [ 70,  85],
#        [ 30,  15],
#        [ 25,  81],
#        [ 12,  42],
#        [ 20,  24],
#        [ 72,  94],
#        [ 25,   0],
#        [ 91,  54],
#        [ 60,  88],
#        [ 45,  54],
#        [ 70,  56],
#        [100,  63],
#        [ 45,  45],
#        [ 45,  54],
#        [ 70,  88],
#        [ 45,  45],
#        [ 70,  20],
#        [100,  81],
#        [100,  96],
#        [100, 100],
#        [ 45,  38],
#        [ 66,  88],
#        [100,  96],
#        [ 54,  98],
#        [ 20,  45],
#        [ 91,  96],
# ...

# %% [markdown]
# Feature Scaling

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
x_train=scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[0.03409091, 0.46      ],
#        [0.61363636, 0.77      ],
#        [0.14772727, 0.33      ],
#        [0.46590909, 0.81      ],
#        [0.09090909, 0.75      ],
#        [1.        , 0.94      ],
#        [0.48863636, 0.69      ],
#        [0.14772727, 0.56      ],
#        [0.14772727, 0.81      ],
#        [0.20454545, 0.48      ],
#        [0.03409091, 0.45      ],
#        [0.78409091, 0.46      ],
#        [0.63636364, 0.77      ],
#        [0.68181818, 0.5       ],
#        [0.5       , 0.56      ],
#        [0.57954545, 0.63      ],
#        [1.        , 0.69      ],
#        [0.26136364, 0.56      ],
#        [0.48863636, 0.33      ],
#        [0.21590909, 0.21      ],
#        [0.48863636, 0.22      ],
#        [0.65909091, 0.85      ],
#        [0.20454545, 0.15      ],
#        [0.14772727, 0.81      ],
#        [0.        , 0.42      ],
#        [0.09090909, 0.24      ],
#        [0.68181818, 0.94      ],
#        [0.14772727, 0.        ],
# ...

# %% [markdown]
# Clustering

# %%
from sklearn.cluster import KMeans
kmean = KMeans(n_clusters=3)
kmean
# Out:
# KMeans(n_clusters=3)

# %% [markdown]
# y_cluster = kmean.fit_predict(x_train)

# %%
y_cluster
# Out:
# array([0, 1, 0, 1, 2, 1, 2, 2, 2, 2, 0, 1, 1, 1, 2, 1, 1, 2, 2, 0, 2, 1,
#        0, 2, 0, 0, 1, 0, 1, 1, 2, 1, 1, 2, 2, 1, 2, 2, 1, 1, 1, 2, 1, 1,
#        1, 0, 1, 2, 1, 1])

# %%
dfmhs['cluster'] = y_cluster

# %%
dfmhS
# Out:
#           Mahasiswa  uts  uas  cluster
# 0             AHMAD   15   46        0
# 1           ARFENDO   66   77        1
# 2         LATIFUDIN   25   33        0
# 3             HENDI   53   81        1
# 4         M. FERYAN   20   75        2
# 5             RENDI  100   94        1
# 6            NUREKA   55   69        2
# 7             INDRA   25   56        2
# 8        MOCH IDWAL   25   81        2
# 9       REYNO YUSUF   30   48        2
# 10    AHMAD MINANUL   15   45        0
# 11           AFIZZA   81   46        1
# 12              RIO   68   77        1
# 13         MUKHOZIN   72   50        1
# 14             ANDY   56   56        2
# 15      STIFEN ZURO   63   63        1
# 16           ROHMAT  100   69        1
# 17        SAFRUDINI   35   56        2
# 18    AFRIZAL AHMAD   55   33        2
# 19   MOHAMMAD HASIB   31   21        0
# 20  MUHAMMAD ENRICO   55   22        2
# 21       MOH. LUKKY   70   85        1
# 22     ADI ARISANDI   30   15        0
# ...

# %%
kmean.cluster_centers_
# Out:
# array([[0.10732323, 0.30111111],
#        [0.76373106, 0.7875    ],
#        [0.34291444, 0.52176471]])

# %% [markdown]
# Visualisasi Data Hasil Clustering

# %%
plt.figure(figsize=(10,8))
plt.scatter(x_train[:,0],x_train[:,1],c=kmean.labels_)
plt.scatter(kmean.cluster_centers_[0,0],kmean.cluster_centers_[0,1],marker='*',s=150,label='Centroid 0')
plt.scatter(kmean.cluster_centers_[1,0],kmean.cluster_centers_[1,1],marker='*',s=150,label='Centroid 1')
plt.scatter(kmean.cluster_centers_[2,0],kmean.cluster_centers_[2,1],marker='*',s=150,label='Centroid 2')
plt.xlabel("UTS")
plt.ylabel("UAS")
plt.legend()

# %% [markdown]
# Mencari K (jumlah cluster) terbaik

# %%
inertias = []
k_range  = range(1,10)
for k in k_range:
    km = KMeans(n_clusters=k).fit(x_train)
    inertias.append(km.inertia_)

# %%
inertias
# Out:
# [7.842257805785124,
#  3.1977734049586775,
#  2.4267319466388484,
#  1.7996082920953016,
#  1.3612797855931946,
#  0.9760937287649221,
#  1.0439096802439982,
#  0.618234273415978,
#  0.4343802083333333]

# %%
plt.xlabel("k")
plt.ylabel("Sum of error")
plt.plot(k_range,inertias)
plt.grid()

# %%
dir(KMeans)

# %%
help(KMeans)
